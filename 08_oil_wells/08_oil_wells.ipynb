# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-и-подготовка-данных" data-toc-modified-id="Загрузка-и-подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка и подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-библиотек-и-датасетов" data-toc-modified-id="Загрузка-библиотек-и-датасетов-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка библиотек и датасетов</a></span></li><li><span><a href="#Разбор-информации-о-датасетах" data-toc-modified-id="Разбор-информации-о-датасетах-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Разбор информации о датасетах</a></span></li><li><span><a href="#Проверка-корреляции-признаков" data-toc-modified-id="Проверка-корреляции-признаков-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Проверка корреляции признаков</a></span></li><li><span><a href="#Проверка-уникальных-значений-и-дубликатов" data-toc-modified-id="Проверка-уникальных-значений-и-дубликатов-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Проверка уникальных значений и дубликатов</a></span></li><li><span><a href="#Анализ-данных-на-графиках" data-toc-modified-id="Анализ-данных-на-графиках-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Анализ данных на графиках</a></span><ul class="toc-item"><li><span><a href="#Датасет-geo_data_0.csv" data-toc-modified-id="Датасет-geo_data_0.csv-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Датасет geo_data_0.csv</a></span></li><li><span><a href="#Датасет-geo_data_1.csv" data-toc-modified-id="Датасет-geo_data_1.csv-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Датасет geo_data_1.csv</a></span></li><li><span><a href="#Датасет-geo_data_2.csv" data-toc-modified-id="Датасет-geo_data_2.csv-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Датасет geo_data_2.csv</a></span></li></ul></li><li><span><a href="#Удаление-описательных-признаков" data-toc-modified-id="Удаление-описательных-признаков-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Удаление описательных признаков</a></span></li></ul></li><li><span><a href="#Обучение-и-проверка-модели" data-toc-modified-id="Обучение-и-проверка-модели-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Обучение и проверка модели</a></span><ul class="toc-item"><li><span><a href="#Формирование-выборок" data-toc-modified-id="Формирование-выборок-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Формирование выборок</a></span></li><li><span><a href="#Обучение-модели" data-toc-modified-id="Обучение-модели-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Обучение модели</a></span><ul class="toc-item"><li><span><a href="#Первый-регион" data-toc-modified-id="Первый-регион-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Первый регион</a></span></li><li><span><a href="#Второй-регион" data-toc-modified-id="Второй-регион-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Второй регион</a></span></li><li><span><a href="#Третий-регион" data-toc-modified-id="Третий-регион-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Третий регион</a></span></li></ul></li><li><span><a href="#Анализ-полученных-результатов" data-toc-modified-id="Анализ-полученных-результатов-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Анализ полученных результатов</a></span></li></ul></li><li><span><a href="#Подготовка-к-расчёту-прибыли" data-toc-modified-id="Подготовка-к-расчёту-прибыли-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Подготовка к расчёту прибыли</a></span><ul class="toc-item"><li><span><a href="#Создание-переменных-ключевых-значений" data-toc-modified-id="Создание-переменных-ключевых-значений-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Создание переменных ключевых значений</a></span></li><li><span><a href="#Расчет-объёма-сырья-для-безубыточной-разработки" data-toc-modified-id="Расчет-объёма-сырья-для-безубыточной-разработки-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Расчет объёма сырья для безубыточной разработки</a></span></li></ul></li><li><span><a href="#Расчёт-прибыли-и-рисков" data-toc-modified-id="Расчёт-прибыли-и-рисков-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Расчёт прибыли и рисков</a></span><ul class="toc-item"><li><span><a href="#Функция-для-расчёта-прибыли" data-toc-modified-id="Функция-для-расчёта-прибыли-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Функция для расчёта прибыли</a></span></li><li><span><a href="#Bootstrap-для-распределения-прибыли" data-toc-modified-id="Bootstrap-для-распределения-прибыли-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Bootstrap для распределения прибыли</a></span></li></ul></li><li><span><a href="#Итоговые-выводы-и-обоснование" data-toc-modified-id="Итоговые-выводы-и-обоснование-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Итоговые выводы и обоснование</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Выбор локации для скважины

# %% [markdown]
# Допустим, вы работаете в добывающей компании «ГлавРосГосНефть». Нужно решить, где бурить новую скважину.
#
# Вам предоставлены пробы нефти в трёх регионах: в каждом 10 000 месторождений, где измерили качество нефти и объём её запасов. Постройте модель машинного обучения, которая поможет определить регион, где добыча принесёт наибольшую прибыль. Проанализируйте возможную прибыль и риски техникой *Bootstrap.*
#
# Шаги для выбора локации:
#
# - В избранном регионе ищут месторождения, для каждого определяют значения признаков;
# - Строят модель и оценивают объём запасов;
# - Выбирают месторождения с самым высокими оценками значений. Количество месторождений зависит от бюджета компании и стоимости разработки одной скважины;
# - Прибыль равна суммарной прибыли отобранных месторождений.

# %% [markdown]
# **Описание данных**
#
# Данные геологоразведки трёх регионов находятся в файлах: <br />
# регион 1 - /datasets/geo_data_0.csv, <br />
# регион 2 - /datasets/geo_data_1.csv, <br />
# регион 3 - /datasets/geo_data_2.csv. <br />
#
# Расшифровка названий столбцов
# - id — уникальный идентификатор скважины;
# - f0, f1, f2 — три признака точек (неважно, что они означают, но сами признаки значимы);
# - product — объём запасов в скважине (тыс. баррелей).
#
# **Условия задачи:**
# - Для обучения модели подходит только линейная регрессия (остальные — недостаточно предсказуемые).
# - При разведке региона исследуют 500 точек, из которых с помощью машинного обучения выбирают 200 лучших для разработки.
# - Бюджет на разработку скважин в регионе — 10 млрд рублей.
# - При нынешних ценах один баррель сырья приносит 450 рублей дохода. Доход с каждой единицы продукта составляет 450 тыс. рублей, поскольку объём указан в тысячах баррелей.
# - После оценки рисков нужно оставить лишь те регионы, в которых вероятность убытков меньше 2.5%. Среди них выбирают регион с наибольшей средней прибылью.
#
# Данные синтетические: детали контрактов и характеристики месторождений не разглашаются.

# %% [markdown]
# **План работы**
#
# **Шаг 1. Загрузить, изучить и подготовить данные**
#
# **Шаг 2. Обучить и проверить модель для каждого региона**
# - Разбить данные на обучающую и валидационную выборки в соотношении 75:25
# - Обучить модель и сделать предсказания на валидационной выборке
# - Сохранить предсказания и правильные ответы на валидационной выборке
# - Показать средний запас предсказанного сырья и RMSE модели
# - Проанализировать результаты
#
# **Шаг 3. Подготовка к расчёту прибыли**
# - Сохранить в отдельных переменных все ключевые значения для расчётов
# - Рассчитать достаточный объём сырья для безубыточной разработки новой скважины. Сравнить полученный объём сырья со средним запасом в каждом регионе
# - Написать выводы по этапу подготовки расчёта прибыли
#
# **Шаг 4. Написать функцию для расчёта прибыли по выбранным скважинам и предсказаниям модели**
# - Выбрать скважины с максимальными значениями предсказаний
# - Просуммировать целевое значение объёма сырья, соответствующее этим предсказаниям
# - Рассчитать прибыль для полученного объёма сырья
#
# **Шаг 5. Посчитать риски и прибыль для каждого региона**
# - Применив технику Bootstrap с 1000 выборок, найти распределение прибыли
# - Найти среднюю прибыль, 95%-й доверительный интервал и риск убытков - отрицательную прибыль
# - Написать выводы: предложить регион для разработки скважин с обоснованием выбора

# %% [markdown]
# ## Загрузка и подготовка данных

# %% [markdown]
# ### Загрузка библиотек и датасетов

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from numpy.random import RandomState
pd.options.display.float_format = '{:.2f}'.format
pd.options.mode.chained_assignment = None
pd.set_option('display.max_columns', None) 
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error 
from scipy import stats as st
import math
import warnings
warnings.filterwarnings("ignore")

# %%
try:
    gd_0 = pd.read_csv('/datasets/geo_data_0.csv', sep=',')
except:
    gd_0 = pd.read_csv('/Users/vadimprimakov/Documents/Yandex_practicum/CSV/08_geo_data_0.csv', sep=',')
    
try:
    gd_1 = pd.read_csv('/datasets/geo_data_1.csv', sep=',')
except:
    gd_1 = pd.read_csv('/Users/vadimprimakov/Documents/Yandex_practicum/CSV/08_geo_data_1.csv', sep=',')
    
try:
    gd_2 = pd.read_csv('/datasets/geo_data_2.csv', sep=',')
except:
    gd_2 = pd.read_csv('/Users/vadimprimakov/Documents/Yandex_practicum/CSV/08_geo_data_2.csv', sep=',')    
    
display(gd_0.head())
display(gd_1.head())
display(gd_2.head())
# Out:
#       id    f0    f1   f2  product
# 0  txEyH  0.71 -0.50 1.22   105.28
# 1  2acmU  1.33 -0.34 4.37    73.04
# 2  409Wp  1.02  0.15 1.42    85.27
# 3  iJLyR -0.03  0.14 2.98   168.62
# 4  Xdl7t  1.99  0.16 4.75   154.04
#       id     f0     f1    f2  product
# 0  kBEdx -15.00  -8.28 -0.01     3.18
# 1  62mP7  14.27  -3.48  1.00    26.95
# 2  vyE1P   6.26  -5.95  5.00   134.77
# 3  KcrkZ -13.08 -11.51  5.00   137.95
# 4  AHL4O  12.70  -8.15  5.00   134.77
#       id    f0    f1    f2  product
# 0  fwXo0 -1.15  0.96 -0.83    27.76
# 1  WJtFt  0.26  0.27 -2.53    56.07
# 2  ovLUW  0.19  0.29 -5.59    62.87
# 3  q6cA6  2.24 -0.55  0.93   114.57
# 4  WPMUX -0.52  1.72  5.90   149.60

# %% [markdown]
# В представленных данных нам предоставлены уникальные идентификаторы скважин, целевой признак объём запасов в скважине мы увидим с столбце product. У каждой скважины есть признаки точек, нам не доступно их описание, что они означают, но сами признаки значимы, можно заметить, что они могут быть как положительные, так и отрицательные.

# %% [markdown]
# ### Разбор информации о датасетах

# %%
print('Размер датасета 0:', gd_0.shape)
print('Размер датасета 1:', gd_1.shape)
print('Размер датасета 2:', gd_2.shape)
# Out:
# Размер датасета 0: (100000, 5)
# Размер датасета 1: (100000, 5)
# Размер датасета 2: (100000, 5)

# %%
print(gd_0.info())
print(gd_1.info())
print(gd_2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       100000 non-null  object
#  1   f0       100000 non-null  float64
#  2   f1       100000 non-null  float64
#  3   f2       100000 non-null  float64
#  4   product  100000 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 3.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       100000 non-null  object
#  1   f0       100000 non-null  float64
#  2   f1       100000 non-null  float64
#  3   f2       100000 non-null  float64
#  4   product  100000 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 3.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# Данные не имеют пропусков, нам доступны данные о 300 000 скважин.

# %%
display(gd_0.describe())
display(gd_1.describe())
display(gd_2.describe())
# Out:
#              f0        f1        f2   product
# count 100000.00 100000.00 100000.00 100000.00
# mean       0.50      0.25      2.50     92.50
# std        0.87      0.50      3.25     44.29
# min       -1.41     -0.85    -12.09      0.00
# 25%       -0.07     -0.20      0.29     56.50
# 50%        0.50      0.25      2.52     91.85
# 75%        1.07      0.70      4.72    128.56
# max        2.36      1.34     16.00    185.36
#              f0        f1        f2   product
# count 100000.00 100000.00 100000.00 100000.00
# mean       1.14     -4.80      2.49     68.83
# std        8.97      5.12      1.70     45.94
# min      -31.61    -26.36     -0.02      0.00
# 25%       -6.30     -8.27      1.00     26.95
# 50%        1.15     -4.81      2.01     57.09
# 75%        8.62     -1.33      4.00    107.81
# max       29.42     18.73      5.02    137.95
#              f0        f1        f2   product
# count 100000.00 100000.00 100000.00 100000.00
# ...

# %% [markdown]
# Для всех датасетов средние близки к медианным значениям, что может говорить о нормальном распределении данных. <br />
# Максимальное значение признаков точек ~ 30, минимальное чуть больше -30, неизвестно что они обозначают, поэтому сложно понять нормален ли такой разброс значений. <br /> Рекомендуется проверить признаки точек на корреляцию, чтобы исключить мультиколлениарность, и, возможно, исключить некоторые из них из исследования.

# %%
display(gd_0.describe())
display(gd_1.describe())
display(gd_2.describe())
# Out:
#              f0        f1        f2   product
# count 100000.00 100000.00 100000.00 100000.00
# mean       0.50      0.25      2.50     92.50
# std        0.87      0.50      3.25     44.29
# min       -1.41     -0.85    -12.09      0.00
# 25%       -0.07     -0.20      0.29     56.50
# 50%        0.50      0.25      2.52     91.85
# 75%        1.07      0.70      4.72    128.56
# max        2.36      1.34     16.00    185.36
#              f0        f1        f2   product
# count 100000.00 100000.00 100000.00 100000.00
# mean       1.14     -4.80      2.49     68.83
# std        8.97      5.12      1.70     45.94
# min      -31.61    -26.36     -0.02      0.00
# 25%       -6.30     -8.27      1.00     26.95
# 50%        1.15     -4.81      2.01     57.09
# 75%        8.62     -1.33      4.00    107.81
# max       29.42     18.73      5.02    137.95
#              f0        f1        f2   product
# count 100000.00 100000.00 100000.00 100000.00
# ...

# %% [markdown]
# ### Проверка корреляции признаков

# %%
plt.rcParams['figure.figsize'] = (7.0, 7.0)
sns.heatmap(gd_0.corr(), annot=True, linewidths=3, linecolor='white')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (7.0, 7.0)
sns.heatmap(gd_1.corr(), annot=True, linewidths=3, linecolor='white')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (7.0, 7.0)
sns.heatmap(gd_2.corr(), annot=True, linewidths=3, linecolor='white')
plt.show()

# %% [markdown]
# Корреляции между признаками практически отсутствует. Но стоит отметить стабильно высокие показатели между "f2" и "product" в каждом из наборов данных. Для второго набора данных такая связь очень высокая, значение близко к 1, это можно объяснить тем, что уникальных значений объемов запасов всего 12, а "f2" имеет маленький разброс значений от 0 до 5. Если бы корреляция была выявлена между признаками (f0, f1 , f2), то один из них пришлось бы удалить из датасета. В данном случае этого не требуется.

# %% [markdown]
# ### Проверка уникальных значений и дубликатов

# %%
gd_0.duplicated().sum()
# Out:
# 0

# %%
gd_1.duplicated().sum()
# Out:
# 0

# %%
gd_2.duplicated().sum()
# Out:
# 0

# %%
gd_0.nunique()
# Out:
# id          99990
# f0         100000
# f1         100000
# f2         100000
# product    100000
# dtype: int64

# %%
gd_1.nunique()
# Out:
# id          99996
# f0         100000
# f1         100000
# f2         100000
# product        12
# dtype: int64

# %%
gd_2.nunique()
# Out:
# id          99996
# f0         100000
# f1         100000
# f2         100000
# product    100000
# dtype: int64

# %%
gd_1.value_counts()
# Out:
# id     f0     f1      f2     product
# 0022J  -1.76  -8.43   2.00   53.91      1
# fCvnc  -8.99  -5.63   3.00   84.04      1
# fDlc6  -3.89  -9.82   4.00   110.99     1
# fDkrz  8.02   -13.99  2.99   80.86      1
# fDk0I  -9.37  -7.66   0.01   3.18       1
#                                        ..
# KaHNv  12.58  -2.37   4.00   107.81     1
# KaFcV  7.11   -1.58   2.00   53.91      1
# Ka7ZM  -4.82  -0.53   -0.01  3.18       1
# Ka6Ap  1.55   -8.10   2.99   84.04      1
# zzzvI  3.32   -4.76   2.99   80.86      1
# Length: 100000, dtype: int64

# %%
gd_1['product'].value_counts()
# Out:
# 53.91     8472
# 26.95     8468
# 84.04     8431
# 57.09     8390
# 3.18      8337
# 80.86     8320
# 30.13     8306
# 134.77    8304
# 110.99    8303
# 0.00      8235
# 137.95    8233
# 107.81    8201
# Name: product, dtype: int64

# %% [markdown]
# Дубликаты в датасетах не выявлено, Есть некоторое число повторящихся id, но признаки у них разные, возможно, некоторые скважины получали измерения в разное время, либо эти скважины поделены на внутренние участки, но имеют одинаковые id.
# В датасете gd_1 по целевому столбцу только 12 уникальных значений, но id при этом разные. Дальнейший анализ может показать, почему так получилось, предположительно, это связано с тем, что данные синтетические.

# %% [markdown]
# ### Анализ данных на графиках

# %%
def plots_describe(gd, column):
    global title
    fig, axs = plt.subplots(ncols=2,figsize=(20,5))
    sns.set(font_scale=1.10)
    distplot = sns.distplot(gd[column],ax=axs[0]).set_title(f'Регион {title} признак {column}',fontsize=20);
    sns.boxplot(gd[column], ax=axs[1]).set_title(f'Регион {title} признак {column}',fontsize=20);

# %% [markdown]
# #### Датасет geo_data_0.csv

# %%
sns.pairplot(gd_0);

# %%
gd = gd_0
title = '1'
plots_describe(gd,'f0')

# %%
gd = gd_0
title = '1'
plots_describe(gd,'f1')

# %%
gd = gd_0
title = '1'
plots_describe(gd,'f2')

# %%
gd = gd_0
title = '1'
plots_describe(gd,'product')

# %% [markdown]
# Признак "f0" на графике показывает пиковые значения в районе -1, 0, 1 и 2. Медиана равна 0.5 <br />
# Признак "f1" показывает пиковые значения в районе -0.5, 0.25, и 1. Медиана равна 0.25  <br />
# Признак "f2" на графике показывает нормальное распределение, медиана равна 2.5. Наблюдаются объекты, которые явно отличаются от остальных, так называемые выбросы. <br />
# Признак  "product" показывает пиковые значения в районе 30, 65, 75, 110, 140, 170. По данным геологоразведки этого региона в нем определенно есть перспективные скважины.

# %% [markdown]
# #### Датасет geo_data_1.csv

# %%
sns.pairplot(gd_1);

# %%
gd = gd_1
title = '2'
plots_describe(gd,'f0')

# %%
gd = gd_1
title = '2'
plots_describe(gd,'f1')

# %%
gd = gd_1
title = '2'
plots_describe(gd,'f2')

# %%
gd = gd_1
title = '2'
plots_describe(gd,'product')

# %% [markdown]
# Признак "f0" на графике показывает пиковые значения в районе -6, 10. Медиана равна 1. Существуют выбросы <br />
# Признак "f1" на графике показывает нормальное распределение. Медиана равна -5. Существуют выбросы  <br />
# Признак "f2" на графике наблюдается необычное отображение, медиана равна 2, значения скошены вправо <br />
# Признак  "product" показывает пиковые значения в районе 0 и 140. Медиана равна 60. По данным геологоразведки этого региона в нем есть скважины с объемом запасов более 100 тыс. баррелей.

# %% [markdown]
# #### Датасет geo_data_2.csv

# %%
sns.pairplot(gd_2);

# %%
gd = gd_2
title = '3'
plots_describe(gd,'f0')

# %%
gd = gd_2
title = '3'
plots_describe(gd,'f1')

# %%
gd = gd_2
title = '3'
plots_describe(gd,'f2')

# %%
gd = gd_2
title = '3'
plots_describe(gd,'product')

# %% [markdown]
# Признак "f0" на графике показывает нормальное распределение, медиана равна 0. Наблюдаются выбросы. <br />
# Признак "f1" на графике показывает нормальное распределение, медиана равна 0. Наблюдаются выбросы.  <br />
# Признак "f2" на графике показывает нормальное распределение, медиана равна 2.5. Наблюдаются выбросы. <br />
# Признак  "product" показывает пиковые значения в районе 30, 65, 80, 110, 140, 160. По данным геологоразведки этого региона более половины скважин обладают запасами более 100 тыс. баррелей.

# %% [markdown]
# ### Удаление описательных признаков

# %% [markdown]
# Признак id — уникальный идентификатор скважины - является описательной для пользователей и не несет ценности для прогнозирования, поэтому данные столбцы можно удалить.

# %%
gd_0 = gd_0.drop('id', axis=1)
gd_1 = gd_1.drop('id', axis=1)
gd_2 = gd_2.drop('id', axis=1)

# %%
display(gd_0.head())
display(gd_1.head())
display(gd_2.head())
# Out:
#      f0    f1   f2  product
# 0  0.71 -0.50 1.22   105.28
# 1  1.33 -0.34 4.37    73.04
# 2  1.02  0.15 1.42    85.27
# 3 -0.03  0.14 2.98   168.62
# 4  1.99  0.16 4.75   154.04
#       f0     f1    f2  product
# 0 -15.00  -8.28 -0.01     3.18
# 1  14.27  -3.48  1.00    26.95
# 2   6.26  -5.95  5.00   134.77
# 3 -13.08 -11.51  5.00   137.95
# 4  12.70  -8.15  5.00   134.77
#      f0    f1    f2  product
# 0 -1.15  0.96 -0.83    27.76
# 1  0.26  0.27 -2.53    56.07
# 2  0.19  0.29 -5.59    62.87
# 3  2.24 -0.55  0.93   114.57
# 4 -0.52  1.72  5.90   149.60

# %% [markdown]
# Данные успешно загружены, проведен анализ признаков, существенная предобработка не требуется. Масштаб значений точек отличается, следовательно перед созданием модели рекомендуется их отмасштабировать.

# %% [markdown]
# ## Обучение и проверка модели

# %% [markdown]
# ### Формирование выборок

# %% [markdown]
# Разобьём данные на обучающую и валидационную выборки в соотношении 75:25, проведем масштабирование количественных признаков, будет быстрее выписать функцию, так как предстоит повторять данные операции в каждом регионе.

# %%
for i in range(0, 3):
    i = str(i)
    X = globals()['gd_' + i].drop('product', axis=1)
    y = globals()['gd_' + i]['product']
    globals()['X_train_' + i],\
    globals()['X_valid_' + i],\
    globals()['y_train_' + i],\
    globals()['y_valid_' + i] = train_test_split(X, y, test_size=0.25, random_state=12345)
    numeric = ['f0', 'f1', 'f2']
    if i == '1':
        scaler = MinMaxScaler()
    else:
        scaler = StandardScaler()
    scaler.fit(globals()['X_train_' + i][numeric])
    globals()['X_train_' + i][numeric] = scaler.transform(globals()['X_train_' + i][numeric])
    globals()['X_valid_' + i][numeric] = scaler.transform(globals()['X_valid_' + i][numeric])
    
    print(globals()['X_train_' + i].shape)
    print(globals()['X_valid_' + i].shape)
    print(globals()['y_train_' + i].shape)
    print(globals()['y_valid_' + i].shape) 
    print()
# Out:
# (75000, 3)
# (25000, 3)
# (75000,)
# (25000,)
#
# (75000, 3)
# (25000, 3)
# (75000,)
# (25000,)
#
# (75000, 3)
# (25000, 3)
# (75000,)
# (25000,)

# %%
display(X_train_0.head())
display(X_valid_0.head())
display(X_train_0.describe())
display(X_valid_0.describe())
# Out:
#          f0    f1    f2
# 27212 -0.54  1.39 -0.09
# 7866   1.46 -0.48  1.21
# 62041  0.26  0.83 -0.20
# 70185 -1.84  0.01 -0.15
# 82230 -1.30  0.99  1.27
#          f0    f1    f2
# 71751  0.52 -0.61 -0.13
# 80493  0.57 -0.09 -0.81
# 2655   0.81 -1.61 -1.34
# 53233  0.22 -1.36 -0.60
# 91141 -0.09  1.43 -0.54
#             f0       f1       f2
# count 75000.00 75000.00 75000.00
# mean      0.00    -0.00     0.00
# std       1.00     1.00     1.00
# min      -2.19    -2.18    -3.89
# 25%      -0.66    -0.89    -0.68
# 50%       0.00    -0.00     0.00
# 75%       0.66     0.89     0.68
# max       2.14     2.17     4.15
#             f0       f1       f2
# count 25000.00 25000.00 25000.00
# mean      0.01     0.00    -0.00
# std       1.00     1.00     1.00
# min      -2.06    -2.10    -4.49
# 25%      -0.65    -0.90    -0.69
# 50%       0.01     0.00    -0.00
# 75%       0.67     0.90     0.67
# max       2.07     2.14     3.85

# %% [markdown]
# Данные успешно разбиты на обучающую и валидационную выборки в соотношении 75:25, масштабирование количественных признаков выполнено.

# %% [markdown]
# ### Обучение модели

# %% [markdown]
# Теперь нам предстоит построить модель линейной регрессии и сделать предсказания на валидационной выборке. Сохранить предсказания и правильные ответы на валидационной выборке. Вывести на экран средний запас предсказанного сырья и RMSE модели.

# %%
def model_lr(geo_data_area, y_column, X_train, X_valid, y_train, y_valid):
    
    X = geo_data_area.drop('product', axis=1)
    y = geo_data_area['product']
    
    parameters = {'fit_intercept':[True,False], 'copy_X':[True, False], 'normalize':[True,False]}
    model = GridSearchCV(estimator=LinearRegression(), param_grid=parameters, cv=5)
    model.fit(X_train, y_train)
    predictions_valid = model.predict(X_valid)
    
    metrics = {}
    metrics['target_real_mean'] = round(y.mean(),2)
    metrics['predictions_valid_mean'] =  round(predictions_valid.mean(),2)
    metrics['mse'] =  round(mean_squared_error(y_valid, predictions_valid),2)
    metrics['rmse'] =  round(metrics['mse'] ** 0.5,2)
    metrics['r2'] =  round(r2_score(y_valid, predictions_valid),2)
    metrics['mae'] =  round(mean_absolute_error(y_valid, predictions_valid),2)
    metrics["best_model_params"] = model.best_params_
    metrics["predicted_valid"] = predictions_valid
    metrics["target_valid"] = y_valid
    
    return metrics

# %% [markdown]
# #### Первый регион

# %%
metrics_gd_0 = model_lr(gd_0, 'product', X_train_0, X_valid_0, y_train_0, y_valid_0)
print(f'Предсказанное среднее значение сырья первого региона: { metrics_gd_0["predictions_valid_mean"] }')
print(f'Фактическое среднее значение запаса сырья в первом регионе: { metrics_gd_0["target_real_mean"]}')
print(f'Среднеквадратическая ошибка в первом регионе: { metrics_gd_0["rmse"] }')
print(f'Параметры лучшей модели в первом регионе: { metrics_gd_0["best_model_params"] }')
# Out:
# Предсказанное среднее значение сырья первого региона: 92.59
# Фактическое среднее значение запаса сырья в первом регионе: 92.5
# Среднеквадратическая ошибка в первом регионе: 37.58
# Параметры лучшей модели в первом регионе: {'copy_X': True, 'fit_intercept': True, 'normalize': True}

# %% [markdown]
# #### Второй регион

# %%
metrics_gd_1 = model_lr(gd_1, 'product', X_train_1, X_valid_1, y_train_1, y_valid_1)
print(f'Предсказанное среднее значение сырья второго региона: { metrics_gd_1["predictions_valid_mean"] }')
print(f'Фактическое среднее значение запаса сырья в первом регионе: { metrics_gd_1["target_real_mean"]}')
print(f'Среднеквадратическая ошибка во втором регионе: { metrics_gd_1["rmse"] }')
print(f'Параметры лучшей модели во втором регионе: { metrics_gd_1["best_model_params"] }')
# Out:
# Предсказанное среднее значение сырья второго региона: 68.73
# Фактическое среднее значение запаса сырья в первом регионе: 68.83
# Среднеквадратическая ошибка во втором регионе: 0.89
# Параметры лучшей модели во втором регионе: {'copy_X': True, 'fit_intercept': True, 'normalize': True}

# %% [markdown]
# #### Третий регион

# %%
metrics_gd_2 = model_lr(gd_2, 'product', X_train_2, X_valid_2, y_train_2, y_valid_2)
print(f'Предсказанное среднее значение сырья третьего региона: { metrics_gd_2["predictions_valid_mean"] }')
print(f'Фактическое среднее значение запаса сырья в первом регионе: { metrics_gd_2["target_real_mean"]}')
print(f'Среднеквадратическая ошибка в третьем регионе: { metrics_gd_2["rmse"] }')
print(f'Параметры лучшей модели в третьем регионе: { metrics_gd_2["best_model_params"] }')
# Out:
# Предсказанное среднее значение сырья третьего региона: 94.97
# Фактическое среднее значение запаса сырья в первом регионе: 95.0
# Среднеквадратическая ошибка в третьем регионе: 40.03
# Параметры лучшей модели в третьем регионе: {'copy_X': True, 'fit_intercept': True, 'normalize': True}

# %% [markdown]
# ### Анализ полученных результатов

# %% [markdown]
# После обучения модели, мы получили первые результаты, отобразим их в наглядной таблице.

# %%
model_results = pd.DataFrame({"Среднее предсказанное, тыс.баррелей":[metrics_gd_0["predictions_valid_mean"], metrics_gd_1["predictions_valid_mean"], metrics_gd_2["predictions_valid_mean"]],
                              "Среднее фактическое, тыс.баррелей":[metrics_gd_0["target_real_mean"], metrics_gd_1["target_real_mean"], metrics_gd_2["target_real_mean"]],
                              "Отклонение, %":[((metrics_gd_0["predictions_valid_mean"]/metrics_gd_0["target_real_mean"])-1)*100,
                                               ((metrics_gd_1["predictions_valid_mean"]/metrics_gd_1["target_real_mean"])-1)*100,
                                              ((metrics_gd_2["predictions_valid_mean"]/metrics_gd_2["target_real_mean"])-1)*100],
                              "RMSE":[metrics_gd_0["rmse"], metrics_gd_1["rmse"], metrics_gd_2["rmse"]],
                              "R2":[metrics_gd_0["r2"], metrics_gd_1["r2"], metrics_gd_2["r2"]],
                              "MAE":[metrics_gd_0["mae"], metrics_gd_1["mae"], metrics_gd_2["mae"]]})

model_results.index = ['Регион 1', 'Регион 2', 'Регион 3']
model_results
# Out:
#           Среднее предсказанное, тыс.баррелей  \
# Регион 1                                92.59
# Регион 2                                68.73
# Регион 3                                94.97
#
#           Среднее фактическое, тыс.баррелей  Отклонение, %  RMSE   R2   MAE
# Регион 1                              92.50           0.10 37.58 0.28 30.92
# Регион 2                              68.83          -0.15  0.89 1.00  0.72
# Регион 3                              95.00          -0.03 40.03 0.21 32.79

# %% [markdown]
# Все 3 модели предсказывают близкие к фактическим значения.<br />
# **Регион 1:**<br />
# Среднее предсказанное: 92.59<br />
# RMSE: 37.58<br />
#
# **Регион 2:**<br />
# Среднее предсказанное: 68.73<br />
# RMSE: 0.89<br />
#
# **Регион 3:**<br />
# Среднее предсказанное: 94.97<br />
# RMSE: 40.03<br />
#
# Чем ниже RMSE, тем лучше данная модель способна “соответствовать” набору данных.<br />
#
# Регион 1 **RMSE: 37.58**<br />
# Регион 2 **RMSE: 0.89**<br />
# Регион 3 **RMSE: 40.03**<br />
#
# Чтобы понимать много это или мало, обычно MSE предсказаний сравнивают со средним MSE по выборке. Чтобы это постоянно не делать, есть метрика коэффициент детерминации R2. Который равен 1 - MSE/MSEсреднее. Чем R2 ближе к единице тем лучше.<br />
#
# Регион 1 **R2: 0.28**<br />
# Регион 2 **R2: 1.00**<br />
# Регион 3 **R2: 0.21**<br />
#
# По данным первого и третьего региона R2 довольно низкие. А показатель R2 по данным второго региона близко подобрался к 1, из-за округления даже получилась единица. такой высокий коэффициент скорей всего из-за очень сильной связи целевого показателя с признаком 'f2', как уже было отмечено на этапе подготовки данных.
#
# Метрика MAE среднее абсолютное отклонение, так же как и RMSE чем ближе к нулю тем лучше, показывает насколько число в прогнозах разошлось с реальными данными.
#
# Регион 1 **MAE: 30.92**<br />
# Регион 2 **MAE: 0.72**<br />
# Регион 3 **MAE: 32.79**<br />
#
# Модель хорошо предсказывает мощность скважины в тыс.баррелей, отклонения по регионам от 0,03 до 0,15%.
#
# Наилучшими прогнозными свойствами обладает модель линейной регрессии с параметрами
# - **'copy_X': True**
# - **fit_intercept': True**
# - **'normalize': True**
#
# Если на данном этапе попытаться предположить, в каком регионе мы получим наибольшую прибыль, основываясь только лишь на выборе региона с максимально предсказанным значением объём запасов в скважине, то мы бы выбирали третий регион. Однако в этом случае мы не проводили оценку рисков, вероятности убытков, поэтому на данном этапе подводить итоги еще рано. Можно переходить к подготовке расчета прибыли.

# %% [markdown]
# ## Подготовка к расчёту прибыли

# %% [markdown]
# ### Создание переменных ключевых значений

# %% [markdown]
# Пройдемся по условиям задачи и определим переменные для ключевых значений:
#
# 1) При разведке региона исследуют 500 точек, из которых с помощью машинного обучения выбирают 200 лучших для разработки.<br />

# %%
exploration_spots = 500 
chosen_spots = 200

# %% [markdown]
# 2) Бюджет на разработку скважин в регионе — 10 млрд рублей. Изменим размерность, в дальнейшем значение в technology_budget выражается в млн. руб <br />

# %%
technology_budget = 10000

# %% [markdown]
# 3) При нынешних ценах один баррель сырья приносит 450 рублей дохода. Доход с каждой единицы продукта составляет 450 тыс. рублей, поскольку объём указан в тысячах баррелей. Изменим размерность, в дальнейшем значение в income_per_barrel выражается в млн. руб<br />

# %%
income_per_barrel = 0.45

# %% [markdown]
# 4) После оценки рисков нужно оставить лишь те регионы, в которых вероятность убытков меньше 2.5%. Среди них выбирают регион с наибольшей средней прибылью.<br />

# %%
loss_probability_min = 0.025

# %% [markdown]
# 5) Применив технику Bootstrap с 1000 выборок, нам предстоит найти распределение прибыли, поэтому введем переменную и для количества выборок.<br />

# %%
bootstrap_samples = 1000

# %% [markdown]
# 6) Для красивого отображения данных зададим число для уменьшения или увеличения количества нулей.<br />

# %%
denomination = 1000

# %% [markdown]
# ### Расчет объёма сырья для безубыточной разработки

# %% [markdown]
# Для расчета достаточного объема сырья для безубыточной разработки новой скважины необходимо:
#
# 1) Вычислить затраты на разработку одной скважины - разделить бюджет на количество скважин выбранных для разработки. Размерность budget_per_pumper - млн.руб. <br />
# 2) Вычислить какое количество сырья в тыс. баррель необходимо добывать для покрытия затрат на разработку скважины.

# %%
budget_per_pumper = technology_budget / chosen_spots
budget_per_pumper
# Out:
# 50.0

# %%
minimum_product_volume = budget_per_pumper / income_per_barrel
print('Необходимый объем сырья для безубыточной разработки 1 скважины в тыс. баррелей {:.2f}'.format(minimum_product_volume))
# Out:
# Необходимый объем сырья для безубыточной разработки 1 скважины в тыс. баррелей 111.11

# %%
gd_0_region = pd.DataFrame(metrics_gd_0["target_valid"])
gd_0_region['доход, млн. руб'] = metrics_gd_0["target_valid"] * income_per_barrel
gd_0_region['предсказание, тыс.бар'] = metrics_gd_0["predicted_valid"]
gd_0_region['регион'] = 0

gd_1_region = pd.DataFrame(metrics_gd_1["target_valid"])
gd_1_region['доход, млн. руб'] = metrics_gd_1["target_valid"] * income_per_barrel
gd_1_region['предсказание, тыс.бар'] = metrics_gd_1["predicted_valid"]
gd_1_region['регион'] = 1

gd_2_region = pd.DataFrame(metrics_gd_2["target_valid"])
gd_2_region['доход, млн. руб'] = metrics_gd_2["target_valid"] * income_per_barrel
gd_2_region['предсказание, тыс.бар'] = metrics_gd_2["predicted_valid"]
gd_2_region['регион'] = 2

# %%
oil_comparison = pd.concat([gd_0_region, gd_1_region, gd_2_region])
oil_comparison = oil_comparison.rename (columns= {'product': 'фактическое, тыс.бар'}) 
oil_comparison.pivot_table(index='регион')
# Out:
#         доход, млн. руб  предсказание, тыс.бар  фактическое, тыс.бар
# регион
# 0                 41.44                  92.59                 92.08
# 1                 30.93                  68.73                 68.72
# 2                 42.70                  94.97                 94.88

# %% [markdown]
# Для разработки **200** лучших перспективных скважин выделено **10 000 млн. руб**. Затраты на разработку одной скважины составляют **50 млн. руб**. Доход с каждой единицы (1000 баррелей) продукта составляет **0.45 млн. руб**. Для достижения точки безубыточности необходимый объем добываемой нефти должен составлять **111.11 тыс. баррелей**.
# Согласно прогнозам, такой объема не достигается ни в одном регионе. Cредние значения запасов сырья для всех трех регионов ниже необходимого объема, что говорит о том, что существует высокая вероятность не окупить затраченный бюджет. На текущий момент, нам известен потенциальный доход, однако, выбирать третий регион для реализации проекта, все также не представляется возможным, так как все еще не учтена вероятность убытков. На следующем этапе проведем проверку ранее созданных моделей для определения скважин с максимальными значениями предсказаний.

# %% [markdown]
# ## Расчёт прибыли и рисков

# %% [markdown]
# ### Функция для расчёта прибыли

# %% [markdown]
# На этом этапе пропишем функцию, которая будет выбирать скважины с максимальными значениями предсказаний (по условиям задачи для разработки берутся 200 лучших скважин. Также она должна просуммировать целевое значение объёма сырья, соответствующее этим предсказаниям и в конечном итоге рассчитать прибыль для полученного объёма сырья. Применять ее будем для каждого региона.

# %%
def profit_predicted(gd_region):
    predict_max200 = gd_region.sort_values(by='предсказание, тыс.бар', ascending=False)[:200]
    product_sum_max200 = math.floor(predict_max200['product'].sum())
    profit_max200 = round(((product_sum_max200 * income_per_barrel) - technology_budget)/1000,4)
    return profit_max200

# %%
print('Прибыль для полученного объёма баррелей нефти в первом регионе: {:.4f} млрд.руб.'.format(profit_predicted(gd_0_region)))
print('Прибыль для полученного объёма баррелей нефти во втором регионе: {:.4f} млрд.руб.'.format(profit_predicted(gd_1_region)))
print('Прибыль для полученного объёма баррелей нефти в третьем регионе: {:.4f} млрд.руб.'.format(profit_predicted(gd_2_region)))
# Out:
# Прибыль для полученного объёма баррелей нефти в первом регионе: 3.3205 млрд.руб.
# Прибыль для полученного объёма баррелей нефти во втором регионе: 2.4151 млрд.руб.
# Прибыль для полученного объёма баррелей нефти в третьем регионе: 2.7102 млрд.руб.

# %% [markdown]
# Отсортировав 200 скважин с наибольшей мощностью в каждом регионе, были произведены подсчеты прибыли за вычетом расходов на разработку. В каждом регионе вышли в плюс, возможная прибыль составляет от 2,4 до 3,3 миллиардов рублей. Однако, и в данном случае подводить итоги еще рано. Лучше всего себя показал первый регион, в котором максимальная прибыль может составлять **3.3205 млрд.руб**, но данные показатели мы можем получить, если проведем геологоразведку по 25 000 скважинам(объем выборки), что в реальности просто невозможно. Согласно требованиям заказчика мы можем провести геологоразведку только по 500 точкам. На следующем этап, применив технику Bootstrap, проанализируем как изменится прибыль исходя из данного ограничения.

# %% [markdown]
# ### Bootstrap для распределения прибыли

# %%
def bootstrap_profit(gd_region):
    global technology_budget
    global loss_probability_min
    state = np.random.RandomState(12345)
    values = []
    for i in range(1000): 
        data = gd_region.sample(n=exploration_spots, random_state=state, replace=True)
        predict_max200 = data.sort_values(by='предсказание, тыс.бар', ascending=False)[:200]
        profit = (predict_max200['доход, млн. руб'].sum() - technology_budget)/1000
        values.append(profit)
    values = pd.Series(values)
    lower = values.quantile(0.025)*denomination
    higher = values.quantile(0.975)*denomination
    loss = values[values<0]*denomination
    mean = values.mean()*denomination
    final_score = 1. * loss.count()/len(values)
    confidence_interval = st.t.interval(0.95, len(values)-1, values.mean(), np.std(values, ddof=1))
    print("Средняя прибыль: {:.2f} млн.руб.".format(mean))
    print("95%-й доверительный интервал: от {:.2f}".format(lower), "млн.руб. до {:.2f}".format(higher), "млн.руб.")
    print("Количество убыточных экспериментов:", loss.count())
    if final_score < loss_probability_min:
        print("Вероятность убытков равна {:.2%} и является меньше допустимой, регион подходит по критериям".format(final_score))
    else:
        print("Вероятность убытков равна {:.2%} и является больше допустимой, регион не подходит по критериям".format(final_score))      
    print("Максимальный убыток: {:.2f} млн.руб".format(loss.min()))
    print("Максимальная прибыль: {:.2f} млрд.руб".format(values.max()))
    
    plt.figure()
    profit_plot = plt.hist(values,  bins=100)
    one_x12, one_y12 = [confidence_interval[0],confidence_interval[0]], [0, 30]
    two_x12, two_y12 = [confidence_interval[1],confidence_interval[1]], [0, 30]
    plt.title('Гистограмма распределения прибыли в выбранном регионе')
    plt.xlabel('Прибыль в млн. рублей')
    plt.plot(one_x12, one_y12, two_x12, two_y12, marker = 'o')

# %%
print('Регион 1:')
bootstrap_profit(gd_0_region)
# Out:
# Регион 1:
# Средняя прибыль: 396.16 млн.руб.
# 95%-й доверительный интервал: от -111.22 млн.руб. до 909.77 млн.руб.
# Количество убыточных экспериментов: 69
# Вероятность убытков равна 6.90% и является больше допустимой, регион не подходит по критериям
# Максимальный убыток: -369.57 млн.руб
# Максимальная прибыль: 1.35 млрд.руб

# %%
print('Регион 2:')
bootstrap_profit(gd_1_region)
# Out:
# Регион 2:
# Средняя прибыль: 456.05 млн.руб.
# 95%-й доверительный интервал: от 33.82 млн.руб. до 852.29 млн.руб.
# Количество убыточных экспериментов: 15
# Вероятность убытков равна 1.50% и является меньше допустимой, регион подходит по критериям
# Максимальный убыток: -192.27 млн.руб
# Максимальная прибыль: 1.15 млрд.руб

# %%
print('Регион 3:')
bootstrap_profit(gd_2_region)
# Out:
# Регион 3:
# Средняя прибыль: 404.40 млн.руб.
# 95%-й доверительный интервал: от -163.35 млн.руб. до 950.36 млн.руб.
# Количество убыточных экспериментов: 76
# Вероятность убытков равна 7.60% и является больше допустимой, регион не подходит по критериям
# Максимальный убыток: -417.86 млн.руб
# Максимальная прибыль: 1.33 млрд.руб

# %% [markdown]
# Произвольным образом выбирая 200 скважин из 500, среднее значение прибыли упало по сравнению с выбором из 25000.
#
# Средняя прибыль Регион 1: **396.16 млн.руб.**<br />
# Вероятность убытков равна **6.90%**<br />
#
# Средняя прибыль Регион 2: **456.05 млн.руб.** <br />
# Вероятность убытков равна **1.50%**<br />
#
# Средняя прибыль Регион 3: **404.40 млн.руб.** <br />
# Вероятность убытков равна **7.60%**
#
# Во втором региона вероятность убытков составляет 1.5%, к тому же в пределах 95%-доверительного интервала добыча все равно остаётся без убыточной. Средняя прибыль выше, чем в остальных регионах.Рекомендуется выбрать регион 2 для разработки скважин.

# %% [markdown]
# ## Итоговые выводы и обоснование

# %% [markdown]
# На первом шаге, был проведен анализ данных, проверены уникальные значения и наличие дубликатов, проведена проверка корреляции признаков, стоит отметить стабильно высокие показатели между "f2" и "product" в каждом из наборов данных. Для второго набора (Регион 2) данных такая связь очень высокая, значение близко к 1.
#
# После первого этапа была проведена процедура формирования обучающих и валидационных выборок в соотношении 75:25, количественных признаков были промасштабированы. Разработаны и обучены три модели Линейной регрессии, параметры подобраны с помощью GridSearchCV для каждого датасета.
# Наилучшими прогнозными свойствами обладает модель линейной регрессии с параметрами
# - **'copy_X': True**
# - **fit_intercept': True**
# - **'normalize': True**

# %%
model_results
# Out:
#           Среднее предсказанное, тыс.баррелей  \
# Регион 1                                92.59
# Регион 2                                68.73
# Регион 3                                94.97
#
#           Среднее фактическое, тыс.баррелей  Отклонение, %  RMSE   R2   MAE
# Регион 1                              92.50           0.10 37.58 0.28 30.92
# Регион 2                              68.83          -0.15  0.89 1.00  0.72
# Регион 3                              95.00          -0.03 40.03 0.21 32.79

# %% [markdown]
# Модель хорошо предсказывает среднюю мощность скважин, отклонения по регионам от 0,03 до 0,15%.
# Несмотря на низкое значение предсказанных и фактических показателей добычи, в лидеры вырывается регион 2, со следующими метриками
# - RMSE = **0.89**<br />
# - MAE = **0.72**<br />
# - коэффициент детерминации R2 = **1.0**. <br />
#
# После определения переменных для ключевых значений, был произведен расчет достаточный объём сырья для безубыточной разработки новой скважины. Он составил **111.11 тыс. баррелей**. Согласно прогнозам, такой среднего объема добычи не достигается ни в одном регионе.
#
# Отсортировав 200 скважин с наибольшей мощностью в каждом регионе, были произведены подсчеты прибыли за вычетом расходов на разработку по фактическим данным.
#
# Прибыль для полученного объёма баррелей нефти в первом регионе: **3.3205 млрд.руб.**<br />
# Прибыль для полученного объёма баррелей нефти во втором регионе: **2.4151 млрд.руб.**<br />
# Прибыль для полученного объёма баррелей нефти в третьем регионе: **2.7102 млрд.руб.**<br />
#
# Согласно требованиям провести геологоразведку разрешено только по 500 точкам. Поэтому на следующем этапе, применив методику Bootstrap, было проанализировано, как изменится прибыль исходя из данного ограничения.
#
# Средняя прибыль Регион 1: **396.16 млн.руб.**<br />
# Вероятность убытков равна **6.90%**<br />
#
# Средняя прибыль Регион 2: **456.05 млн.руб.** <br />
# Вероятность убытков равна **1.50%**<br />
#
# Средняя прибыль Регион 3: **404.40 млн.руб.** <br />
# Вероятность убытков равна **7.60%**
#
# Несмотря на лидерство первого региона на большой выборке, существуют высокая вероятность убытков разрабатывать в этом регионе 6,9%.
#
# После применения техники Bootstrap с 1000 выборок, стало ясно, что регион 2, будет предпочтительнее, так как вероятность убытков составляет **1.5%**, к тому же в пределах 95%-доверительного интервала добыча все равно остаётся **безубыточной**. Средняя прибыль выше, чем в остальных регионах и составляет **456.05 млн.руб.**.
